# %% [markdown]
# # 1. Find out how many males and females participated in the test.

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("StudentsPerformance.csv")

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
group=data.groupby('gender')

# %%
group.count()
# Out:
#         race/ethnicity  parental level of education  lunch  \
# gender
# female             518                          518    518
# male               482                          482    482
#
#         test preparation course  math score  reading score  writing score
# gender
# female                      518         518            518            518
# male                        482         482            482            482

# %% [markdown]
# There are 518 Females, and 482 Males

# %% [markdown]
# # 2. What do you think about the students' parental level of education?

# %%
groupg=data.groupby('parental level of education')

# %%
groupg.count()
# Out:
#                              gender  race/ethnicity  lunch  \
# parental level of education
# associate's degree              222             222    222
# bachelor's degree               118             118    118
# high school                     196             196    196
# master's degree                  59              59     59
# some college                    226             226    226
# some high school                179             179    179
#
#                              test preparation course  math score  \
# parental level of education
# associate's degree                               222         222
# bachelor's degree                                118         118
# high school                                      196         196
# master's degree                                   59          59
# some college                                     226         226
# some high school                                 179         179
#
# ...

# %% [markdown]
# The students parental level of education is highest in "some college", lowest in "master's degree"

# %% [markdown]
# # 3. Who scores the most on average for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
group3=data.groupby('gender')

# %%
group3.mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
group4=data.groupby('test preparation course')

# %%
group4.mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
# # 4. What do you think about the scoring variation for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
group5=data.groupby('gender')

# %%
group5.var()
# Out:
#         math score  reading score  writing score
# gender
# female  256.958593     207.677438     220.369327
# male    211.889097     200.211010     202.413924

# %%
group6=data.groupby('test preparation course')

# %%
group6.var()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                210.884027     183.265864     175.202612
# none                     246.668662     213.419851     226.251739

# %% [markdown]
# # 5. The management needs your help to give bonus points to the top 25% of students based on their maths score, so how will you help the management to achieve this.

# %%
data.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000
